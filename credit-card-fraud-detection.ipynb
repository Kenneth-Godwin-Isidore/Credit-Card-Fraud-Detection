# %% [markdown]
# # **Here we are using the Credit Card Fraud Detection public dataset avaialable in Kaggle to create a model to categorize the transactions.**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/creditcardfraud/creditcard.csv

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('/kaggle/input/creditcardfraud/creditcard.csv')

# %%
df.head(7)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # **The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions**

# %% [markdown]
# # **Splitting the data into train and test in 80:20 ratio, such that the training set and testing set have the target variable in the right count.**

# %%
df3=df[df['Class']==1]

# %%
df3.shape
# Out:
# (492, 31)

# %% [markdown]
# # **Let's Check for trends in the data with positive class**

# %%
for i in df3.columns:
    if(i!="Class" and i!='Time'):
        sns.distplot(result[i])
        plt.show()

# %%
df5=df3[394:]

# %%
df3=df3[:394]

# %%
df4=df[df['Class']==0]

# %%
df6=df4[227452:]

# %%
df4=df4[:227452]

# %%
frames=[df3,df4]
result = pd.concat(frames)

# %%
result['Class'].value_counts()
# Out:
# 0    227452
# 1       394
# Name: Class, dtype: int64

# %%
frames=[df5,df6]
result2 = pd.concat(frames)

# %%
result2['Class'].value_counts()
# Out:
# 0    56863
# 1       98
# Name: Class, dtype: int64

# %%
sns.barplot(x=result['Class'].value_counts().head(5),y=result['Class'].value_counts())
plt.show()

# %%
for i in result.columns:
    if(i!="Class" and i!='Time'):
        sns.distplot(result[i])
        plt.show()

# %%
fig = plt.figure(figsize = (12, 9))
sns.heatmap(result.corr(), vmax = .8, square = True)
plt.show()

# %%
y_train=result['Class']
x_train=result.drop('Class', axis=1)

y_test=result2['Class']
x_test=result2.drop('Class', axis=1)

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score
from collections import Counter

# %%
model = LogisticRegression() 
model.fit(x_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
predictions=model.predict(x_test)

# %%
Counter(predictions)
# Out:
# Counter({0: 56939, 1: 22})

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.998560418531978

# %% [markdown]
# # **Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb=GaussianNB()

# %%
nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
predictions=nb.predict(x_test)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9927669809167676

# %% [markdown]
# # **Stochastic Gradient Descent**

# %%
from sklearn.linear_model import SGDClassifier

# %%
sgd= SGDClassifier( shuffle=True, random_state=101)

# %%
sgd.fit(x_train,y_train)
# Out:
# SGDClassifier(random_state=101)

# %%
predictions=sgd.predict(x_test)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9982795245869981

# %% [markdown]
# # **K-Nearest Neighbours**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=20)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
predictions=knn.predict(x_test)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9982795245869981

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree=DecisionTreeClassifier()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions=dtree.predict(x_test)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9990344270641316

# %% [markdown]
# # **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfm=RandomForestClassifier()

# %%
rfm.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions=rfm.predict(x_test)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9994382121100402

# %% [markdown]
# # **Support Vector Machine**

# %%
from sklearn.svm import SVC

# %%
svm=SVC(kernel="linear", C=0.025, random_state=101)

# %%
svm.fit(x_train,y_train)
# Out:
# SVC(C=0.025, kernel='linear', random_state=101)

# %%
predictions=svm.predict(x_test)

# %%
accuracy_score(y_test,predictions)
# Out:
# 0.9982795245869981

# %% [markdown]
# # **Random Forest Classifier shows the highest accuracy.**
